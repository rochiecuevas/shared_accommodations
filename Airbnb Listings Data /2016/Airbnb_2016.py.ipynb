# %%
# Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import csv
import os
import re #for filtering list of files

# %%
#List csv files 
files = os.listdir()[0:16]
r = re.compile(".*listings")
newlist = list(filter(r.match,files))
newlist
# Out:
# ['20161001 listings.csv',
#  '20160602 listings.csv',
#  '20161203 listings.csv',
#  '20160902 listings.csv',
#  '20160802 listings.csv',
#  '20160702 listings.csv',
#  '20160502 listings.csv',
#  '20160403 listings.csv',
#  '20160202 listings.csv',
#  '20161102 listings.csv']

# %%
#list of csv file contents 

airbnb_dflist = [pd.read_csv(file) for file in newlist]
airbnb_dflist
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2903: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# [            id                            listing_url       scrape_id  \
#  0      8411606   https://www.airbnb.com/rooms/8411606  20161001161403
#  1     10961737  https://www.airbnb.com/rooms/10961737  20161001161403
#  2     14252951  https://www.airbnb.com/rooms/14252951  20161001161403
#  3     15285867  https://www.airbnb.com/rooms/15285867  20161001161403
#  4     11187767  https://www.airbnb.com/rooms/11187767  20161001161403
#  5      1931937   https://www.airbnb.com/rooms/1931937  20161001161403
#  6      9904485   https://www.airbnb.com/rooms/9904485  20161001161403
#  7      7856443   https://www.airbnb.com/rooms/7856443  20161001161403
#  8      2134100   https://www.airbnb.com/rooms/2134100  20161001161403
# ...

# %%
#parsing the names for the dataframes 
file_name = [file_name[0:8] for file_name in newlist]
file_name
# Out:
# ['20161001',
#  '20160602',
#  '20161203',
#  '20160902',
#  '20160802',
#  '20160702',
#  '20160502',
#  '20160403',
#  '20160202',
#  '20161102']

# %%
#convert two lists into a dict 


airbnb_df_dict = dict(zip(file_name, airbnb_dflist))

airbnb_df_dict
# Out:
# {'20161001':             id                            listing_url       scrape_id  \
#  0      8411606   https://www.airbnb.com/rooms/8411606  20161001161403
#  1     10961737  https://www.airbnb.com/rooms/10961737  20161001161403
#  2     14252951  https://www.airbnb.com/rooms/14252951  20161001161403
#  3     15285867  https://www.airbnb.com/rooms/15285867  20161001161403
#  4     11187767  https://www.airbnb.com/rooms/11187767  20161001161403
#  5      1931937   https://www.airbnb.com/rooms/1931937  20161001161403
#  6      9904485   https://www.airbnb.com/rooms/9904485  20161001161403
#  7      7856443   https://www.airbnb.com/rooms/7856443  20161001161403
#  8      2134100   https://www.airbnb.com/rooms/2134100  20161001161403
#  9      6938818   https://www.airbnb.com/rooms/6938818  20161001161403
#  10     9395222   https://www.airbnb.com/rooms/9395222  20161001161403
#  11     8001958   https://www.airbnb.com/rooms/8001958  20161001161403
# ...

# %%
airbnb_df_dict['20161001']['neighbourhood_cleansed']
# Out:
# 0               Seacliff
# 1               Seacliff
# 2               Seacliff
# 3               Seacliff
# 4               Seacliff
# 5               Seacliff
# 6               Seacliff
# 7               Seacliff
# 8               Seacliff
# 9               Seacliff
# 10              Seacliff
# 11              Seacliff
# 12              Seacliff
# 13              Seacliff
# 14              Seacliff
# 15              Seacliff
# 16              Seacliff
# 17              Seacliff
# 18        Haight Ashbury
# 19        Haight Ashbury
# 20        Haight Ashbury
# 21        Haight Ashbury
# 22        Haight Ashbury
# 23        Haight Ashbury
# 24        Haight Ashbury
# 25        Haight Ashbury
# 26        Haight Ashbury
# 27        Haight Ashbury
# 28        Haight Ashbury
# 29        Haight Ashbury
#               ...
# 8729    Western Addition
# 8730    Western Addition
# 8731    Western Addition
# 8732    Western Addition
# 8733    Western Addition
# 8734    Western Addition
# ...

# %%
n = []

for key in airbnb_df_dict: 
  for item in airbnb_df_dict[key].items():
    print(airbnb_df_dict[key]['''neighbourhood_cleansed',''])
  #@airbnb_df_dict = list[n].keys()

data.head(1)
# Out:
# 0               Seacliff
# 1               Seacliff
# 2               Seacliff
# 3               Seacliff
# 4               Seacliff
# 5               Seacliff
# 6               Seacliff
# 7               Seacliff
# 8               Seacliff
# 9               Seacliff
# 10              Seacliff
# 11              Seacliff
# 12              Seacliff
# 13              Seacliff
# 14              Seacliff
# 15              Seacliff
# 16              Seacliff
# 17              Seacliff
# 18        Haight Ashbury
# 19        Haight Ashbury
# 20        Haight Ashbury
# 21        Haight Ashbury
# 22        Haight Ashbury
# 23        Haight Ashbury
# 24        Haight Ashbury
# 25        Haight Ashbury
# 26        Haight Ashbury
# 27        Haight Ashbury
# 28        Haight Ashbury
# 29        Haight Ashbury
#               ...
# 8729    Western Addition
# 8730    Western Addition
# 8731    Western Addition
# 8732    Western Addition
# 8733    Western Addition
# 8734    Western Addition
# ...

# %%
# Create a path to the csv and read it into a Pandas DataFrame
#csv_path = "20160202 listings.csv"

#airbnb20160202_df = pd.read_csv("20160202 listings.csv")

#airbnb20160202_df.head()
# Out:
#          id                            listing_url       scrape_id  \
# 0   3168359   https://www.airbnb.com/rooms/3168359  20160201235901
# 1   9824673   https://www.airbnb.com/rooms/9824673  20160201235901
# 2   9033278   https://www.airbnb.com/rooms/9033278  20160201235901
# 3  10469182  https://www.airbnb.com/rooms/10469182  20160201235901
# 4   8087607   https://www.airbnb.com/rooms/8087607  20160201235901
#
#   last_scraped                                name  \
# 0   2016-02-02   Charming & Private Ideal location
# 1   2016-02-02       STUNNING HOUSE BY OCEAN BEACH
# 2   2016-02-02                Gorgeous Ocean Views
# 3   2016-02-02  Cozy Garden Studio - Private Entry
# 4   2016-02-02   Single Room Beautiful Beach Condo
#
#                                              summary  \
# 0                                                NaN
# 1  Our charming single family home has been taste...
# 2  See the dolphins while hiking lands end, go to...
# ...

# %%
#Create DataFrame with column: "neighbourhood_cleansed","property_type","price"
#airbnb20160202_df = airbnb20160202_df[["neighbourhood_cleansed","property_type","price"]]
#airbnb20160202_df.head()
# Out:
#   neighbourhood_cleansed property_type    price
# 0               Seacliff     Apartment  $224.00
# 1               Seacliff         House  $325.00
# 2               Seacliff         House  $300.00
# 3               Seacliff         House  $120.00
# 4               Seacliff     Apartment   $79.00

# %%
#Calculate the annual price
# daily_data = airbnb20160202_df["price"].str.replace("$","")
# daily_data = daily_data.str.replace(",","")
# daily_data = daily_data.astype(float)
# airbnb20160202_df["annual rate"] = daily_data*365
# airbnb20160202_df.head()
# Out:
#   neighbourhood_cleansed property_type    price  annual rate
# 0               Seacliff     Apartment  $224.00      81760.0
# 1               Seacliff         House  $325.00     118625.0
# 2               Seacliff         House  $300.00     109500.0
# 3               Seacliff         House  $120.00      43800.0
# 4               Seacliff     Apartment   $79.00      28835.0

# %%
#Add date to the DataFrame 
# airbnb20160202_df["date"] = pd.to_datetime("2016-02")
# airbnb20160202_df.head()
# Out:
#   neighbourhood_cleansed property_type    price  annual rate       date
# 0               Seacliff     Apartment  $224.00      81760.0 2016-02-01
# 1               Seacliff         House  $325.00     118625.0 2016-02-01
# 2               Seacliff         House  $300.00     109500.0 2016-02-01
# 3               Seacliff         House  $120.00      43800.0 2016-02-01
# 4               Seacliff     Apartment   $79.00      28835.0 2016-02-01
