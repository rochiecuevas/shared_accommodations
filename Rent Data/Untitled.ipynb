# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import csv
pd.set_option('display.max_rows', 1000)

# %%
rent_df = pd.read_csv("rent_year_csv.csv")
rent_df["Avg Price"] = ""
rent_df
# Out:
#               Region Name   Region Type  Data Type      2011      2012  \
# 0                 Bayview  neighborhood  All Homes   $2,852    $2,961
# 1          Bernal Heights  neighborhood  All Homes   $2,448    $2,393
# 2             Buena Vista  neighborhood  All Homes   $2,864    $2,951
# 3          Corona Heights  neighborhood  All Homes   $3,554    $3,799
# 4              Cow Hollow  neighborhood  All Homes   $3,431    $3,702
# 5          Crocker Amazon  neighborhood  All Homes   $4,407    $4,387
# 6         Diamond Heights  neighborhood  All Homes   $2,518    $2,495
# 7                Downtown  neighborhood  All Homes   $3,029    $3,075
# 8               Excelsior  neighborhood  All Homes   $2,567    $2,720
# 9      Financial District  neighborhood  All Homes   $2,537    $2,495
# 10            Forest Hill  neighborhood  All Homes   $4,228    $4,086
# 11          Forest Knolls  neighborhood  All Homes   $3,979    $3,901
# ...
