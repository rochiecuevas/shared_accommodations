# %%
# Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import csv

# %matplotlib notebook

# %%
csv_path = "hp_and_rent_grouped.csv"

merged_df = pd.read_csv(csv_path, encoding='utf8', engine='python')

merged_df.head()
# Out:
#      Neighborhood  Unnamed: 0    Year  Assessed Land Value  Pct Change  \
# 0         Bayview         6.5  2013.5        190512.858289    4.170000
# 1  Bernal Heights        16.5  2013.5        268491.454817    6.726667
# 2     Buena Vista        26.5  2013.5        487987.841867    5.866667
# 3  Corona Heights        36.5  2013.5        394108.123417    4.850000
# 4      Cow Hollow        46.5  2013.5        614482.066967    5.825000
#
#    Yearly Rent Price  Avg Rent Rate        Lat         Lng
# 0       35644.333333   37087.571429  37.730416 -122.384424
# 1       43599.666667   45048.428571  37.738950 -122.415201
# 2       53112.333333   54370.142857  37.806505 -122.420778
# 3       52034.000000   53150.428571  37.761812 -122.443185
# 4       63147.833333   64405.571429  37.798033 -122.439646

# %%
neighborhood = merged_df['Neighborhood']
price = merged_df['Assessed Land Value']
rent = merged_df['Avg Rent Rate']

# %%
N = 5
priceMeans = price
rentMeans = rent
neigh = neighborhood

# Set x and y limits
plt.xlim(-0.25, len(neigh))
plt.ylim(0, max(price)+10)

#objects = ('Python', 'C++', 'Java', 'Perl', 'Scala', 'Lisp')
y_pos = np.arange(len(neigh))
performance = price
 
plt.bar(y_pos, performance, align='center', alpha=.5)
plt.xticks(y_pos, neigh, rotation = 'vertical')
#plt.get_xticklabels(xlabels, rotation=90)
plt.ylabel('Price')
plt.title('Housing Price')
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
multi_df = {}
multi_df["Neighborhood"] = merged_df['Neighborhood']
multi_df["Price"] = merged_df['Assessed Land Value']
multi_df["Rent"] = merged_df['Avg Rent Rate']

# %%
multi_df = pd.DataFrame(multi_df)
multi_df["Price"] = multi_df["Price"] / 5
multi_df.head()
# Out:
#      Neighborhood          Price          Rent
# 0         Bayview   38102.571658  37087.571429
# 1  Bernal Heights   53698.290963  45048.428571
# 2     Buena Vista   97597.568373  54370.142857
# 3  Corona Heights   78821.624683  53150.428571
# 4      Cow Hollow  122896.413393  64405.571429

# %%
# Pandas can also plot multiple columns if the DataFrame includes them
multi_plot = multi_df.plot(kind="bar", figsize=(20,5))

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(multi_df["Neighborhood"], rotation=90)

plt.show()
plt.tight_layout()
plt.savefig('HP_Rent.png')
# Out:
# <img src="data:image/png;base64,..." width="2000">

# %%
csv_path = "hp_and_rent.csv"

year_df = pd.read_csv(csv_path, encoding='utf8', engine='python')

year_df.head(10)
# Out:
#    Unnamed: 0  Unnamed: 0.1    Neighborhood  Year  Assessed Land Value  \
# 0           0             4         Bayview  2011        175691.806133
# 1           1             5         Bayview  2012        177818.914467
# 2           2             6         Bayview  2013        182203.741400
# 3           3             7         Bayview  2014        185691.451367
# 4           4             8         Bayview  2015        198571.039233
# 5           5             9         Bayview  2016        223100.197133
# 6           6            14  Bernal Heights  2011        228865.782800
# 7           7            15  Bernal Heights  2012        241607.198400
# 8           8            16  Bernal Heights  2013        252609.859300
# 9           9            17  Bernal Heights  2014        270243.422800
#
#    Pct Change   Region Type  Data Type  Yearly Rent Price  Avg Rent Rate  \
# 0        0.14  neighborhood  All Homes              30723   37087.571429
# ...

# %%
# Plot the world average as a line chart
years = 6
del year_df['Unnamed: 0']
del year_df['Unnamed: 0.1']
#year_df = year_df.set_index("Neighborhood")
#bay_price = year_df.loc['Neighborhood']

                        
# price_avg, = plt.plot(years, bay_price, color="blue", label="Bayview Average" )

                        
# # # Plot the unemployment values for a single country
# rent_one, = plt.plot(years, year_df.loc['USA',["2010","2011","2012","2013","2014"]], 
#                          color="green",label=combined_unemployed_data.loc['USA',"Country Name"])

# # Create a legend for our chart
# #plt.legend(handles=[world_avg, country_one], loc="best")

# # Show the chart
# plt.show()

# %%
year_df.head(8)
# Out:
#      Neighborhood  Year  Assessed Land Value  Pct Change   Region Type  \
# 0         Bayview  2011        175691.806133        0.14  neighborhood
# 1         Bayview  2012        177818.914467        1.21  neighborhood
# 2         Bayview  2013        182203.741400        2.47  neighborhood
# 3         Bayview  2014        185691.451367        1.91  neighborhood
# 4         Bayview  2015        198571.039233        6.94  neighborhood
# 5         Bayview  2016        223100.197133       12.35  neighborhood
# 6  Bernal Heights  2011        228865.782800        3.96  neighborhood
# 7  Bernal Heights  2012        241607.198400        5.57  neighborhood
#
#    Data Type  Yearly Rent Price  Avg Rent Rate           City        Lat  \
# 0  All Homes              30723   37087.571429  San Francisco  37.730416
# 1  All Homes              28821   37087.571429  San Francisco  37.730416
# 2  All Homes              30433   37087.571429  San Francisco  37.730416
# ...

# %%
year_df['Pct Change'] = year_df['Pct Change'] * 10000

# %%
year_df.head()
# Out:
#   Neighborhood  Year  Assessed Land Value  Pct Change   Region Type  \
# 0      Bayview  2011        175691.806133      1400.0  neighborhood
# 1      Bayview  2012        177818.914467     12100.0  neighborhood
# 2      Bayview  2013        182203.741400     24700.0  neighborhood
# 3      Bayview  2014        185691.451367     19100.0  neighborhood
# 4      Bayview  2015        198571.039233     69400.0  neighborhood
#
#    Data Type  Yearly Rent Price  Avg Rent Rate           City        Lat  \
# 0  All Homes              30723   37087.571429  San Francisco  37.730416
# 1  All Homes              28821   37087.571429  San Francisco  37.730416
# 2  All Homes              30433   37087.571429  San Francisco  37.730416
# 3  All Homes              35338   37087.571429  San Francisco  37.730416
# 4  All Homes              42870   37087.571429  San Francisco  37.730416
#
#           Lng
# 0 -122.384424
# 1 -122.384424
# 2 -122.384424
# 3 -122.384424
# 4 -122.384424

# %%
prev_neigh = 'None'
for index, neigh in year_df.iterrows():
     if neigh["Neighborhood"] != prev_neigh:
        process = year_df.loc[year_df["Neighborhood"] == neigh["Neighborhood"]]
        p_years=[]
        p_amt=[]
        r_amt=[]
        c_pct=[]
        for index, county in process.iterrows():
            p_years.append(county["Year"])
            p_amt.append(county['Assessed Land Value'])
            r_amt.append(county['Yearly Rent Price'])
            c_pct.append(county['Pct Change'])
        price, = plt.plot(p_years, p_amt, color="blue", label= neigh["Neighborhood"] + " Price Average")
        rent, = plt.plot(p_years, r_amt, color="red", label=neigh["Neighborhood"] + " Rent Average")
        per, = plt.plot(p_years, c_pct, color="green", label=neigh["Neighborhood"] + " Pct Change")
        # # Create a legend for our chart

        # Create a legend for our chart
        plt.legend(handles=[price, rent, per], loc="best")
        # Show the chart
        plt.show()    
        prev_neigh = neigh["Neighborhood"]

# %%
bayview = year_df.loc[year_df["Neighborhood"] == "Bayview"]
type(bayview)

bernal = year_df.loc[year_df["Neighborhood"] == "Bernal Heights"]
type(bernal)

bayview
# Out:
#   Neighborhood  Year  Assessed Land Value  Pct Change   Region Type  \
# 0      Bayview  2011        175691.806133        0.14  neighborhood
# 1      Bayview  2012        177818.914467        1.21  neighborhood
# 2      Bayview  2013        182203.741400        2.47  neighborhood
# 3      Bayview  2014        185691.451367        1.91  neighborhood
# 4      Bayview  2015        198571.039233        6.94  neighborhood
# 5      Bayview  2016        223100.197133       12.35  neighborhood
#
#    Data Type  Yearly Rent Price  Avg Rent Rate           City        Lat  \
# 0  All Homes              30723   37087.571429  San Francisco  37.730416
# 1  All Homes              28821   37087.571429  San Francisco  37.730416
# 2  All Homes              30433   37087.571429  San Francisco  37.730416
# 3  All Homes              35338   37087.571429  San Francisco  37.730416
# 4  All Homes              42870   37087.571429  San Francisco  37.730416
# ...

# %%
p_years=[]
p_amt=[]
for index, county in bayview.iterrows():
    p_years.append(county["Year"])
    p_amt.append(county['Assessed Land Value'])

# %%
p_years
# Out:
# [2011, 2012, 2013, 2014, 2015, 2016]

# %%
r_years=[]
r_amt=[]
for index, county in bayview.iterrows():
    r_years.append(county["Year"])
    r_amt.append(county['Yearly Rent Price'])

# %%
r_years
# Out:
# [2011, 2012, 2013, 2014, 2015, 2016]

# %%
price, = plt.plot(p_years, p_amt, color="blue", label="Price Average")
rent, = plt.plot(r_years, r_amt, color="red", label="Rent Average")
# # Create a legend for our chart

# Create a legend for our chart
plt.legend(handles=[price, rent])
# Show the chart
plt.show()

# %%
# Creates a list from 0 to 5 with each step being 0.1 higher than the last
x_axis = np.arange(0, 5, 0.1)
x_axis
e_x = [np.exp(x) for x in x_axis]
e_x

plt.plot(x_axis, e_x)
plt.show()
